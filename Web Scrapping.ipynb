# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_page')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
header_tags=soup.find('a',href_='/wiki/Wikipedia')
header_tags
#Header tags not getting displayed the output after run is empty as it moves to next execution line

# %%
page=requests.get('https://www.imdb.com/list/ls091520106/')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top 100 Movies Bucket List - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls091520106/" rel="canonical"/>
# ...

# %%
Name=soup.find('h3',class_="lister-item-header")
Name
# Out:
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt0111161/">The Shawshank Redemption</a>
# <span class="lister-item-year text-muted unbold">(1994)</span>
# </h3>

# %%
Name.text
# Out:
# '\n1.\nThe Shawshank Redemption\n(1994)\n'

# %%
Ratings=soup.find('div',class_="ratings-bar")
Ratings
#Output not getting displayed

# %%
Year_of_Release=soup.find('span',class_="lister-item-year text-muted unbold")
Year_of_Release
# Out:
# <span class="lister-item-year text-muted unbold">(1994)</span>

# %% [raw]
# import pandas as pd
# df=pd.DataFrame({'Name':name,'Rating':'rating','Year_of_Release':year of release})
# df

# %%
#Tried but output not getting displayed neither any error showing please help

# %%
#IMDB TOP 100 Indian Movies
# !pip install bs4 
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.imdb.com/india/top-rated-indian-movies')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <style>
#             body#styleguide-v2 #root {
#                 box-shadow: none;
#             }
#         </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top Rated Indian Movies - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
# ...

# %%
name=soup.find('td',class_="titleColumn")
name
# Out:
# <td class="titleColumn">
#       1.
#       <a href="/title/tt15097216/" title="T.J. Gnanavel (dir.), Suriya, Lijo Mol Jose">Jai Bhim</a>
# <span class="secondaryInfo">(2021)</span>
# </td>

# %%
name.text
# Out:
# '\n      1.\n      Jai Bhim\n(2021)\n'

# %%
Year_of_Realease=soup.find('span',class_="secondaryInfo")
Year_of_Realease
# Out:
# <span class="secondaryInfo">(2021)</span>

# %%
Rating=soup.find('td',class_="ratingColumn imdbRating")            
Rating
# Out:
# <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 161,996 user ratings">8.5</strong>
# </td>

# %%
Rating.text
# Out:
# '\n8.5\n'

# %%
names=[]
for i in soup.find_all('td',class_="titleCoulmn"):
    names.append(i.titleColumn)
names
# Out:
# []

# %%
#Showing empty list as output

# %%
import pandas as pd
df=pd.DataFrame({'Name':name,'Rating':rating,'Year_of_Release':year of release})
df
# Out:
#   File "<ipython-input-46-6fb41f9822e8>", line 2
#     df=pd.DataFrame({'Name':name,'Rating':rating,'Year_of_Release':year of release})
#                                                                         ^
# SyntaxError: invalid syntax

# %%
#Showing errors for data frame

# %%
#Ladies bags
page=requests.get('https://meesho.com/bags-ladies/pl/p7vbp')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-2"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-6"></script><script async="">
#               window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'UA-113318580-2', {
#                 page_path: window.location.pathname,
#               });
#           </script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZB97HR591S"></script><script async="">
#               window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'G-ZB97HR591S', {
#                 page_path: window.location.pathname,
#               });
#           </script><script async="">
# ...

# %%
product_name=soup.find('div',class_="Card__BaseCard-sc-b3n78k-0 irlVhK ShippingInfo__DetailCard-sc-dflqn4-0 cYnJAT 8px")
product_name
No display of output no errors too

# %%
product_name=(soup.find)'div',class_="Card__BaseCard-sc-b3n78k-0 irlVhK ShippingInfo__DetailCard-sc-dflqn4-0 cYnJAT ShippingInfo__DetailCard-sc-dflqn4-0 cYnJAT" color="white"><span color="greyT2" font-size="18px" font-weight="demi" class="Text__StyledText-sc-oo0kvp-0 elstub">Stylish Diva Fashion Tote Handbag for Women</span><div class="Card__BaseCard-sc-b3n78k-0 ftaSSh ShippingInfo__PriceRow-sc-dflqn4-2 TEOer ShippingInfo__PriceRow-sc-dflqn4-2 TEOer" color="white" h4 color="greyBase" font-size="32px" font-weight="bold" class="Text__StyledText-sc-oo0kvp-0 fyTUEs">₹260</h4><p color="greyT2" class="Text__StyledText-sc-oo0kvp-0 bWSOET Paragraph__StyledParagraphBody2StrikeThrough-sc-69qp0d-0 hEkmRy ShippingInfo__ParagraphBody2StrikeThroughStyled-sc-dflqn4-8 cnLyze Paragraph__StyledParagraphBody2StrikeThrough-sc-69qp0d-0 hEkmRy ShippingInfo__ParagraphBody2StrikeThroughStyled-sc-dflqn4-8 cnLyze" font-size="16px" font-weight="book">₹360</p><span color="greenBase" font-size="18px" font-weight="demi" class="Text__StyledText-sc-oo0kvp-0 jENgNp"28% off span class="Tooltip__StyledSpan-sc-17ntqqp-0 cRFYPd ShippingInfo__MrpTooltipStyled-sc-dflqn4-11 dXTVsI" title="Price Details"><svg viewBox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg" height="16" width="16" iconSize="20" class="Icon-sc-1iwi4w1-0 boupAk"g clip-path="url(#info_svg__clip0)" fill="#666"><path d="M10 0C4.48 0 0 4.48 0 10s4.48 10 10 10 10-4.48 10-10S15.52 0 10 0zm0 18.44c-4.65 0-8.44-3.79-8.44-8.44 0-4.65 3.79-8.44 8.44-8.44 4.65 0 8.44 3.79 8.44 8.44 0 4.65-3.79 8.44-8.44 8.44z"></path><path fill-rule="evenodd" clip-rule="evenodd" d="M10 4.825a1 1 0 100 2 1 1 0 000-2zm0 3.017a1 1 0 00-1 1v5.333a1 1 0 002 0V8.842a1 1 0 00-1-1z"></path></g><defs><clipPath id="info_svg__clip0"><path fill="#fff" d="M0 0h20v20H0z"></path></clipPath></defs></svg></span></div><div class="Card__BaseCard-sc-b3n78k-0 iBCjCr ShippingInfo__DiscountRow-sc-dflqn4-15 iEZeIa ShippingInfo__DiscountRow-sc-dflqn4-15 iEZeIa" color="white"><svg viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg" height="16" width="16" color="greenT2" iconSize="20" class="Icon-sc-1iwi4w1-0 jabcjO"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.833 5.733c0 .186 1.006 1.745 1.006 1.745.215.312-.844 2.27-.844 2.27-.105.151-.168 2.029-.168 2.029-.001.385-1.961 1.317-1.961 1.317-.17.058-1.276 1.54-1.276 1.54-.218.31-2.328-.139-2.328-.139-.17-.057-1.898.462-1.898.462-.352.118-1.806-1.541-1.806-1.541-.105-.151-1.796-.793-1.796-.793-.35-.12-.595-2.356-.595-2.356 0-.186-1.005-1.744-1.005-1.744-.215-.312.844-2.271.844-2.271.104-.151.167-2.029.167-2.029.002-.385 1.962-1.317 1.962-1.317.17-.058 1.275-1.54 1.275-1.54.218-.31 2.089.353 2.089.353.17.058 2.138-.676 2.138-.676l1.805 1.541c.106.151 1.797.793 1.797.793.35.12.594 2.356.594 2.356zM6.761 6.761a.875.875 0 11-1.238-1.237.875.875 0 011.238 1.237zm2.865-1.236a.6.6 0 11.848.849l-4.101 4.1a.6.6 0 11-.849-.848l4.102-4.1zm.846 4.95a.875.875 0 11-1.238-1.238.875.875 0 011.238 1.237z" fill="#06A759"></path></svg><p color="greyT1" class="Text__StyledText-sc-oo0kvp-0 fCJVtz ShippingInfo__DiscountTextParagraph-sc-dflqn4-14 bbcVhL ShippingInfo__DiscountTextParagraph-sc-dflqn4-14 bbcVhL" font-size="16px" font-weight="book">₹100 discount on 1st order</p></div><div class="Card__BaseCard-sc-b3n78k-0 ftaSSh ShippingInfo__BadgeRow-sc-dflqn4-10 biSiQs ShippingInfo__BadgeRow-sc-dflqn4-10 biSiQs" color="white"><div class="Badge__StyledBadge-sc-1o15k3y-0 dSqlNm"span color="greyT1" font-size="12px" font-weight="demi" class="Text__StyledText-sc-oo0kvp-0 iFGSag"
product_name
#Output not getiing  showing errors
# Out:
#   File "<ipython-input-63-e7b384c1de5b>", line 1
# ...

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.icc-cricket.com/')
page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-27bf8203ef83> in <module>
# ----> 1 page=requests.get('https://www.icc-cricket.com/')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
page=requests.get('https://corevms.com/')
page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-45bb16408088> in <module>
# ----> 1 page=requests.get('https://corevms.com/')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
page=requests.get('https://www.nobroker.in/')
page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-634837bb5cc6> in <module>
# ----> 1 page=requests.get('https://www.nobroker.in/')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.nobroker.in/')
page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-634837bb5cc6> in <module>
# ----> 1 page=requests.get('https://www.nobroker.in/')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5a32a5f49fe3> in <module>
# ----> 1 page=requests.get('https://www.dineout.co.in')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-fa1496ec12a6> in <module>
# ----> 1 page=requests.get('https://www.bewakoof.com/women-tshirts?ga_q=tshirts')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
from bs4 import BeautifulSoup
import requests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-27bf8203ef83> in <module>
# ----> 1 page=requests.get('https://www.icc-cricket.com/')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
page=requests.get('https://www.dineout.co.in')
page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5a32a5f49fe3> in <module>
# ----> 1 page=requests.get('https://www.dineout.co.in')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
page=requests.get('https://corevms.com/')
page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-45bb16408088> in <module>
# ----> 1 page=requests.get('https://corevms.com/')
#       2 page
#
# NameError: name 'requests' is not defined

# %%
from bs4 import BeautifulSoup
import requests
page=requests.get('https://www.nobroker.in')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
house_title=soup.find('span',itemprop_="name")
house_title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea27e4ae1ef3> in <module>
# ----> 1 house_title=soup.find('span',itemprop_="name")
#       2 house_title
#
# NameError: name 'soup' is not defined
